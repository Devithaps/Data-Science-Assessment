# %%
# !pip install pandas numpy openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ACER\\Desktop\\Notebook Jupyter'

# %%
df = pd.read_excel(r"C:\Users\ACER\Desktop\Notebook Jupyter\ABC Company.xlsx")

# %%
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df['height'] = np.random.randint(150, 181, size=len(df))

# %%
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.
import matplotlib.pyplot as plt
team_counts = df['Team'].value_counts()
team_counts
team_percent = (team_counts / len(df)) * 100
team_percent

# Visualization
plt.figure(figsize=(8,6))
team_counts.plot(kind='bar', color='violet')
plt.title("Employee Distribution Across Teams")
plt.xlabel("Team")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Insights
print("Insights:The bar graph titled Employee Distribution Across Teams displays the number of employees in each team. It shows that the New Orleans Pelicans have the highest number of employees (19), while the Orlando Magic and Minnesota Timberwolves have the lowest number (14 each). Most other teams have around 15-16 employees.")
# Out:
# Insights:The bar graph titled Employee Distribution Across Teams displays the number of employees in each team. It shows that the New Orleans Pelicans have the highest number of employees (19), while the Orlando Magic and Minnesota Timberwolves have the lowest number (14 each). Most other teams have around 15-16 employees.

# %%
# Pie chart for percentage split
team_percent.plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title("Percentage Split of Employees by Team")
plt.show()

# %%
#Insights
print("Insights:The pie chart visually represents the percentage distribution of employees across different teams. From the chart, we can observe that no single team constitutes a significantly large portion of the total employees, indicating a relatively even distribution. While the New Orleans Pelicans team has the highest individual share, it's still a small percentage of the total, and most teams hover around 3-4% of the total workforce, reflecting a balanced employee allocation across the various teams.")
# Out:
# Insights:The pie chart visually represents the percentage distribution of employees across different teams. From the chart, we can observe that no single team constitutes a significantly large portion of the total employees, indicating a relatively even distribution. While the New Orleans Pelicans team has the highest individual share, it's still a small percentage of the total, and most teams hover around 3-4% of the total workforce, reflecting a balanced employee allocation across the various teams.

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Segregate employees based on their positions within the company.
import seaborn as sns
import matplotlib.pyplot as plt

position_counts = df['Position'].value_counts()

# Visualization
plt.figure(figsize=(8,6))
sns.barplot(x=position_counts.index, y=position_counts.values, hue=position_counts.index, palette="viridis", legend=False)
plt.title("Employees by Position")
plt.xlabel("Position")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
#Insights:
print("Insights:'Employees by Position', showed the distribution of employees across different positions. It revealed that 'SG' has the highest number of employees (102), followed by 'PF' with 100 employees. 'PG' has 92, 'SF' has 85, and 'C' has the least with 79 employees. This indicates a relatively balanced distribution, with a slight concentration in guard and forward positions.")
# Out:
# Insights:'Employees by Position', showed the distribution of employees across different positions. It revealed that 'SG' has the highest number of employees (102), followed by 'PF' with 100 employees. 'PG' has 92, 'SF' has 85, and 'C' has the least with 79 employees. This indicates a relatively balanced distribution, with a slight concentration in guard and forward positions.

# %%
#Identify the predominant age group among employees.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Define bins and labels
bins = [20, 30, 40, 50, 60]
labels = ['20-29', '30-39', '40-49', '50-59']

# Create age groups
df['age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Count age groups
age_group_counts = df['age_group'].value_counts().reindex(labels) 

# Visualization
plt.figure(figsize=(8,6))
#sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette="coolwarm")
plt.bar(age_group_counts.index, age_group_counts.values, color=sns.color_palette("coolwarm", len(age_group_counts)))
plt.title("Predominant Age Group of Employees")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %%
#Insights:
print(" 'Predominant Age Group of Employees', shows that the largest number of employees fall within the '20-29' age group, with 334 individuals. The next significant group is '30-39' with 119 employees. There are very few employees in the '40-49' age group (only 3), and no employees are observed in the '50-59' age group. This indicates that the workforce is predominantly young, with the vast majority of employees being under 40 years old.")
# Out:
#  'Predominant Age Group of Employees', shows that the largest number of employees fall within the '20-29' age group, with 334 individuals. The next significant group is '30-39' with 119 employees. There are very few employees in the '40-49' age group (only 3), and no employees are observed in the '50-59' age group. This indicates that the workforce is predominantly young, with the vast majority of employees being under 40 years old.

# %%
#Discover which team and position have the highest salary expenditure.

import matplotlib.pyplot as plt

salary_by_team = df.groupby('Team')['Salary'].sum()
salary_by_position = df.groupby('Position')['Salary'].sum()

# Visualization
plt.figure(figsize=(8,6))
salary_by_team.plot(kind='bar', color='pink')
plt.title("Salary Expenditure by Team")
plt.xlabel("Total Salary")
plt.ylabel("Team")
plt.show()

plt.figure(figsize=(8,6))
salary_by_position.plot(kind='bar', color='lightblue')
plt.title("Salary Expenditure by Position")
plt.xlabel("Total Salary")
plt.ylabel("Position")
plt.show()

print("Highest Salary Team:", salary_by_team.idxmax())
print("Highest Salary Position:", salary_by_position.idxmax())
# Out:
# Highest Salary Team: Cleveland Cavaliers
# Highest Salary Position: C

# %%
#Insights:
print("Salary Expenditure by Team: The first bar graph visualizes the total salary expenditure for each team. The output explicitly states that the Cleveland Cavaliers have the highest salary expenditure, indicating they invest the most in player salaries among all teams. It is the tallest bar in the first plot.Salary Expenditure by Position: The second bar graph shows the total salary expenditure per player position. It highlights that the 'C' position has the highest total salary expenditure. This suggests that centers, on average or due to fewer highly paid individuals, command the highest total salaries across the league, followed by 'PG', 'PF', 'SF', and 'SG' in decreasing order of total salary expenditure.")
# Out:
# Salary Expenditure by Team: The first bar graph visualizes the total salary expenditure for each team. The output explicitly states that the Cleveland Cavaliers have the highest salary expenditure, indicating they invest the most in player salaries among all teams. It is the tallest bar in the first plot.Salary Expenditure by Position: The second bar graph shows the total salary expenditure per player position. It highlights that the 'C' position has the highest total salary expenditure. This suggests that centers, on average or due to fewer highly paid individuals, command the highest total salaries across the league, followed by 'PG', 'PF', 'SF', and 'SG' in decreasing order of total salary expenditure.

# %%
#Investigate if there's any correlation between age and salary, and represent it visually.
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization
plt.figure(figsize=(8,6))
sns.scatterplot(x='Age', y='Salary', data=df, alpha=0.6)
sns.regplot(x='Age', y='Salary', data=df, scatter=False, color='red')
plt.title("Correlation Between Age and Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

correlation = df['Age'].corr(df['Salary'])
print("Correlation between Age and Salary:", correlation)
# Out:
# Correlation between Age and Salary: 0.21400941226570971

# %%
#Insights:
print("'Correlation Between Age and Salary', is a scatter plot showing the relationship between an employee's age and their salary, along with a regression line.The correlation coefficient between Age and Salary is approximately 0.214, suggesting a weak positive linear relationship. Salaries generally rise as age increases, but the relationship is not very strong. Younger employees display a wide range of salaries, suggesting that age is only one of many factors influencing earnings. Some younger professionals earn exceptionally high salaries, while some older employees earn less than their peers.")
# Out:
# 'Correlation Between Age and Salary', is a scatter plot showing the relationship between an employee's age and their salary, along with a regression line.The correlation coefficient between Age and Salary is approximately 0.214, suggesting a weak positive linear relationship. Salaries generally rise as age increases, but the relationship is not very strong. Younger employees display a wide range of salaries, suggesting that age is only one of many factors influencing earnings. Some younger professionals earn exceptionally high salaries, while some older employees earn less than their peers.
